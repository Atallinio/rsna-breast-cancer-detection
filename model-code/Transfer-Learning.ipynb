# %% [markdown]
# # Breast Cancer Detection

# %% [markdown]
# *The following is a solution to the RSNA Screeening Mammography Breast Cancer Detection Dataset*

# %%
import tensorflow as tf
import tensorflow_io as tfio
import tensorflow_datasets as tfds
import keras
import os
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split

import cv2

import os
import logging
import random
import pickle
import math

from multiprocessing import cpu_count
# Out:
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1728237428.250045      13 common_lib.cc:798] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="local"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:479
# D1006 17:57:08.258215161      13 config.cc:196]                        gRPC EXPERIMENT call_status_override_on_cancellation   OFF (default:OFF)
# D1006 17:57:08.258229003      13 config.cc:196]                        gRPC EXPERIMENT call_v3                                OFF (default:OFF)
# D1006 17:57:08.258232370      13 config.cc:196]                        gRPC EXPERIMENT canary_client_privacy                  ON  (default:ON)
# D1006 17:57:08.258234770      13 config.cc:196]                        gRPC EXPERIMENT capture_base_context                   ON  (default:ON)
# D1006 17:57:08.258237036      13 config.cc:196]                        gRPC EXPERIMENT client_idleness                        ON  (default:ON)
# D1006 17:57:08.258239337      13 config.cc:196]                        gRPC EXPERIMENT client_privacy                         ON  (default:ON)
# D1006 17:57:08.258241555      13 config.cc:196]                        gRPC EXPERIMENT dapper_request_wire_size               OFF (default:OFF)
# D1006 17:57:08.258243728      13 config.cc:196]                        gRPC EXPERIMENT empty_experiment                       OFF (default:OFF)
# D1006 17:57:08.258245858      13 config.cc:196]                        gRPC EXPERIMENT event_engine_client                    OFF (default:OFF)
# D1006 17:57:08.258247949      13 config.cc:196]                        gRPC EXPERIMENT event_engine_dns                       ON  (default:ON)
# D1006 17:57:08.258250114      13 config.cc:196]                        gRPC EXPERIMENT event_engine_listener                  ON  (default:ON)
# D1006 17:57:08.258252365      13 config.cc:196]                        gRPC EXPERIMENT free_large_allocator                   OFF (default:OFF)
# D1006 17:57:08.258254509      13 config.cc:196]                        gRPC EXPERIMENT google_no_envelope_resolver            OFF (default:OFF)
# D1006 17:57:08.258256644      13 config.cc:196]                        gRPC EXPERIMENT http2_stats_fix                        OFF (default:OFF)
# D1006 17:57:08.258258772      13 config.cc:196]                        gRPC EXPERIMENT keepalive_fix                          OFF (default:OFF)
# D1006 17:57:08.258260904      13 config.cc:196]                        gRPC EXPERIMENT keepalive_server_fix                   ON  (default:ON)
# D1006 17:57:08.258263199      13 config.cc:196]                        gRPC EXPERIMENT loas_do_not_prefer_rekey_next_protocol OFF (default:OFF)
# D1006 17:57:08.258265391      13 config.cc:196]                        gRPC EXPERIMENT loas_prod_to_cloud_prefer_pfs_ciphers  OFF (default:OFF)
# D1006 17:57:08.258267548      13 config.cc:196]                        gRPC EXPERIMENT monitoring_experiment                  ON  (default:ON)
# D1006 17:57:08.258269736      13 config.cc:196]                        gRPC EXPERIMENT multiping                              OFF (default:OFF)
# D1006 17:57:08.258271878      13 config.cc:196]                        gRPC EXPERIMENT peer_state_based_framing               OFF (default:OFF)
# D1006 17:57:08.258274070      13 config.cc:196]                        gRPC EXPERIMENT pending_queue_cap                      ON  (default:ON)
# D1006 17:57:08.258276306      13 config.cc:196]                        gRPC EXPERIMENT pick_first_happy_eyeballs              ON  (default:ON)
# D1006 17:57:08.258278486      13 config.cc:196]                        gRPC EXPERIMENT promise_based_client_call              OFF (default:OFF)
# D1006 17:57:08.258280570      13 config.cc:196]                        gRPC EXPERIMENT promise_based_inproc_transport         OFF (default:OFF)
# D1006 17:57:08.258282695      13 config.cc:196]                        gRPC EXPERIMENT promise_based_server_call              OFF (default:OFF)
# D1006 17:57:08.258284901      13 config.cc:196]                        gRPC EXPERIMENT registered_method_lookup_in_transport  ON  (default:ON)
# D1006 17:57:08.258287063      13 config.cc:196]                        gRPC EXPERIMENT rfc_max_concurrent_streams             ON  (default:ON)
# D1006 17:57:08.258289320      13 config.cc:196]                        gRPC EXPERIMENT round_robin_delegate_to_pick_first     ON  (default:ON)
# D1006 17:57:08.258292306      13 config.cc:196]                        gRPC EXPERIMENT rstpit                                 OFF (default:OFF)
# D1006 17:57:08.258294579      13 config.cc:196]                        gRPC EXPERIMENT schedule_cancellation_over_write       OFF (default:OFF)
# D1006 17:57:08.258296902      13 config.cc:196]                        gRPC EXPERIMENT server_privacy                         ON  (default:ON)
# D1006 17:57:08.258299206      13 config.cc:196]                        gRPC EXPERIMENT tcp_frame_size_tuning                  OFF (default:OFF)
# D1006 17:57:08.258301444      13 config.cc:196]                        gRPC EXPERIMENT tcp_rcv_lowat                          OFF (default:OFF)
# D1006 17:57:08.258303611      13 config.cc:196]                        gRPC EXPERIMENT trace_record_callops                   OFF (default:OFF)
# D1006 17:57:08.258305782      13 config.cc:196]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size    OFF (default:OFF)
# D1006 17:57:08.258307871      13 config.cc:196]                        gRPC EXPERIMENT v3_backend_metric_filter               OFF (default:OFF)
# D1006 17:57:08.258310020      13 config.cc:196]                        gRPC EXPERIMENT v3_channel_idle_filters                ON  (default:ON)
# D1006 17:57:08.258312215      13 config.cc:196]                        gRPC EXPERIMENT v3_compression_filter                  ON  (default:ON)
# D1006 17:57:08.258314375      13 config.cc:196]                        gRPC EXPERIMENT v3_server_auth_filter                  OFF (default:OFF)
# D1006 17:57:08.258316492      13 config.cc:196]                        gRPC EXPERIMENT work_serializer_clears_time_cache      OFF (default:OFF)
# D1006 17:57:08.258318575      13 config.cc:196]                        gRPC EXPERIMENT work_serializer_dispatch               OFF (default:OFF)
# D1006 17:57:08.258320755      13 config.cc:196]                        gRPC EXPERIMENT write_size_cap                         ON  (default:ON)
# D1006 17:57:08.258322967      13 config.cc:196]                        gRPC EXPERIMENT write_size_policy                      ON  (default:ON)
# D1006 17:57:08.258325158      13 config.cc:196]                        gRPC EXPERIMENT wrr_delegate_to_pick_first             ON  (default:ON)
# I1006 17:57:08.258479368      13 ev_epoll1_linux.cc:123]               grpc epoll fd: 59
# D1006 17:57:08.258490949      13 ev_posix.cc:113]                      Using polling engine: epoll1
# D1006 17:57:08.269010410      13 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D1006 17:57:08.269019372      13 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D1006 17:57:08.269026637      13 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D1006 17:57:08.269029573      13 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D1006 17:57:08.269032507      13 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D1006 17:57:08.269035508      13 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin"
# D1006 17:57:08.269059291      13 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D1006 17:57:08.269076830      13 dns_resolver_plugin.cc:43]            Using EventEngine dns resolver
# D1006 17:57:08.269092045      13 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D1006 17:57:08.269112003      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D1006 17:57:08.269118861      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D1006 17:57:08.269122037      13 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D1006 17:57:08.269128390      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D1006 17:57:08.269131432      13 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D1006 17:57:08.269134367      13 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D1006 17:57:08.269137956      13 certificate_provider_registry.cc:33]  registering certificate provider factory for "file_watcher"
# D1006 17:57:08.269166588      13 channel_init.cc:157]                  Filter server-auth not registered, but is referenced in the after clause of grpc-server-authz when building channel stack SERVER_CHANNEL
# I1006 17:57:08.270928485      13 ev_epoll1_linux.cc:359]               grpc epoll fd: 61
# I1006 17:57:08.271969893      13 tcp_socket_utils.cc:689]              Disabling AF_INET6 sockets because ::1 is not available.
# I1006 17:57:08.287703596     101 socket_utils_common_posix.cc:452]     Disabling AF_INET6 sockets because ::1 is not available.
# I1006 17:57:08.287751915     101 socket_utils_common_posix.cc:379]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E1006 17:57:08.292857246     100 oauth2_credentials.cc:238]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {grpc_status:2, created_time:"2024-10-06T17:57:08.292843992+00:00"}

# %%
# Detect hardware, return appropriate distribution strategy
try:
    TPU = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', TPU.master())
except ValueError:
    print('Running on CPU or GPU')
    TPU = None

if TPU:
    IS_TPU = True
    tf.config.experimental_connect_to_cluster(TPU)
    tf.tpu.experimental.initialize_tpu_system(TPU)
    STRATEGY = tf.distribute.experimental.TPUStrategy(TPU)
else:
    IS_TPU = False
    STRATEGY = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

#clear_output()
N_REPLICAS = STRATEGY.num_replicas_in_sync
print(f'N_REPLICAS: {N_REPLICAS}, IS_TPU: {IS_TPU}')
# Out:
# Running on TPU
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728237445.742770      13 service.cc:145] XLA service 0x5b59ed501900 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728237445.742816      13 service.cc:153]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1728237445.742821      13 service.cc:153]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1728237445.742823      13 service.cc:153]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1728237445.742826      13 service.cc:153]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1728237445.742829      13 service.cc:153]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1728237445.742832      13 service.cc:153]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1728237445.742834      13 service.cc:153]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1728237445.742837      13 service.cc:153]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# N_REPLICAS: 8, IS_TPU: True

# %%
# Image dimensions
IMG_HEIGHT = 1456
IMG_WIDTH = 728
N_CHANNELS = 1
INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, 1)
N_SAMPLES_TFRECORDS = 548

# Peak Learning Rate
EPOCHS = 15

# Batch size
BATCH_SIZE = 8 * N_REPLICAS

# Augmentation
BRIGHTNESS = 0.10
CONTRAST = (0.90, 1.10)
JPEG_QUALITY = (90, 100)
CROP_RATIO = (0.80, 1.00)

IS_INTERACTIVE = os.environ['KAGGLE_KERNEL_RUN_TYPE'] == 'Interactive'
VERBOSE = 1 if IS_INTERACTIVE else 2

# Tensorflow AUTO flag
AUTO = tf.data.experimental.AUTOTUNE

print(f'BATCH_SIZE: {BATCH_SIZE}')
# Out:
# BATCH_SIZE: 64

# %%
'''IMG_HEIGHT = 512
IMG_WIDTH = 256'''
# Out:
# 'IMG_HEIGHT = 512\nIMG_WIDTH = 256'

# %%
MIXED_PRECISION = False
DEVICE = 'TPU'

if MIXED_PRECISION:
    if 'TPU' in DEVICE:
        policy_type = 'mixed_bfloat16'
    else:
        policy_type = 'mixed_float16'
else:
    policy_type = 'float32'
policy = tf.keras.mixed_precision.Policy(policy_type)
tf.keras.mixed_precision.set_global_policy(policy)
print(f'Computation dtype: {tf.keras.mixed_precision.global_policy().compute_dtype}')
print(f'Variable dtype: {tf.keras.mixed_precision.global_policy().variable_dtype}')
# Out:
# Computation dtype: float32
# Variable dtype: float32

# %% [markdown]
# # Preporcessing

# %%
# TFRecord file paths
tfrecords = sorted(tf.io.gfile.glob('/kaggle/input/dataset-rsna-bcd-1456x728-final-tfrecords/*.tfrecords'))
print(f'Found {len(tfrecords)} TFRecords')

# Train Test Split
train_tfrecords, valid_tfrecords = train_test_split(
    tfrecords,
    train_size=0.80,
    random_state=42,
    shuffle=True)
print(f'# Train TFRecords: {len(train_tfrecords)}, # Valid TFRecords: {len(valid_tfrecords)}')
# Out:
# Found 100 TFRecords
# # Train TFRecords: 80, # Valid TFRecords: 20

# %%
def create_dataset(tfrecords, batch_size=32, valid=False):
    ignore_order = tf.data.Options()
    ignore_order.experimental_deterministic = False
    # Create dataset path/label
    dataset = tf.data.TFRecordDataset(tfrecords,num_parallel_reads=AUTO,compression_type='GZIP')

    # Decode mapping
    dataset = dataset.map(decoder, num_parallel_calls=AUTO)
    # Val/Debug cases
    if not valid:
        dataset = dataset.filter(undersample_majority)
        
        dataset = dataset.map(augmenter, num_parallel_calls=AUTO)
        dataset = dataset.with_options(ignore_order)
        
        dataset = dataset.shuffle(1024)
        dataset = dataset.repeat()
    if valid:
        dataset = dataset.map(expand_label, num_parallel_calls=AUTO)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

def decoder(record_bytes):
    features = tf.io.parse_single_example(record_bytes, {
        'image': tf.io.FixedLenFeature([], tf.string),
        'target': tf.io.FixedLenFeature([], tf.int64),
        'patient_id': tf.io.FixedLenFeature([], tf.int64)})
    img = tf.io.decode_png(features['image'], channels=N_CHANNELS)
    img = tf.reshape(img, [IMG_HEIGHT, IMG_WIDTH, N_CHANNELS])
    label = features['target']
    return img, label

def undersample_majority(img, label):
    return label == 1 or tf.random.uniform([]) > 2/3

def tf_rand_int(minval, maxval, dtype=tf.int64):
    minval = tf.cast(minval, dtype)
    maxval = tf.cast(maxval, dtype)
    return tf.random.uniform(shape=(), minval=minval, maxval=maxval, dtype=dtype)

def augmenter(img, label):
    # Pixels
    img = tf.image.random_brightness(img, BRIGHTNESS)
    img = tf.image.random_contrast(img, *CONTRAST)
    img = tf.image.random_jpeg_quality(img, *JPEG_QUALITY)
    # Crop
    ratio = tf.random.uniform([], *CROP_RATIO)
    img_height_crop = tf.cast(ratio * IMG_HEIGHT, tf.int32)
    img_width_crop = tf.cast(ratio * IMG_WIDTH, tf.int32)
    img_height_offset = tf_rand_int(0, IMG_HEIGHT - img_height_crop)
    img_width_offset = 0
    img = tf.slice(img, [img_height_offset, img_width_offset, 0],
                   [img_height_crop, img_width_crop, N_CHANNELS])
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    # Clip
    img = tf.clip_by_value(img, 0, 255)
    img = tf.cast(img, tf.uint8)
    img = img / 255
    label = tf.expand_dims(label, axis=-1)
    return img, label

def expand_label(img,label):
    img = img / 255
    label = tf.expand_dims(label, axis=-1)
    return img, label

# %%
# Get Train/Validation datasets
train_dataset = create_dataset(train_tfrecords, valid=False)
valid_dataset = create_dataset(valid_tfrecords, valid=True)

TRAIN_STEPS_PER_EPOCH = (len(train_tfrecords) * N_SAMPLES_TFRECORDS) // BATCH_SIZE
VAL_STEPS_PER_EPOCH = (len(valid_tfrecords) * N_SAMPLES_TFRECORDS) // BATCH_SIZE
print(f'TRAIN_STEPS_PER_EPOCH: {TRAIN_STEPS_PER_EPOCH}, VAL_STEPS_PER_EPOCH: {VAL_STEPS_PER_EPOCH}')
# Out:
# TRAIN_STEPS_PER_EPOCH: 685, VAL_STEPS_PER_EPOCH: 171

# %%
# Sanity checking
def check_dataset(dataset):
    image, label = next(iter(dataset))
    image = image.numpy()
    #clear_output()
    print(f"X_batch shape: {image.shape}, y_batch shape: {label.shape}")
    print(f"X_batch dtype: {image.dtype}, y_batch dtype: {label.dtype}")
    print(f"X_batch min: {image.min():.2f}, max: {image.max():.2f}")

check_dataset(train_dataset)
# Out:
# X_batch shape: (64, 1456, 728, 1), y_batch shape: (64, 1)
# X_batch dtype: float32, y_batch dtype: <dtype: 'int64'>
# X_batch min: 0.00, max: 1.00

# %% [markdown]
# # Creating the Model

# %%
@keras.saving.register_keras_serializable()
class pFBeta(tf.keras.Metric):
    def __init__(self, beta=1, name='pF1', **kwargs):
        super().__init__(name=name, **kwargs)
        self.beta = beta
        self.epsilon = 1e-10
        self.pos = self.add_weight(name='pos', initializer='zeros')
        self.ctp = self.add_weight(name='ctp', initializer='zeros')
        self.cfp = self.add_weight(name='cfp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.keras.ops.cast(y_true, tf.float32)
        y_pred = tf.keras.ops.clip(y_pred, 0, 1)
        pos = tf.keras.ops.cast(tf.keras.ops.sum(y_true), tf.float32)
        ctp = tf.keras.ops.cast(tf.keras.ops.sum(y_pred[y_true == 1]), tf.float32)
        cfp = tf.keras.ops.cast(tf.keras.ops.sum(y_pred[y_true == 0]), tf.float32)
        self.pos.assign_add(pos)
        self.ctp.assign_add(ctp)
        self.cfp.assign_add(cfp)

    def result(self):
        beta2 = self.beta * self.beta
        prec = self.ctp / (self.ctp + self.cfp + self.epsilon)
        reca = self.ctp / (self.pos + self.epsilon)
        return (1 + beta2) * prec * reca / ((beta2 * prec + reca) + self.epsilon) 
    
    def reset_state(self):
        self.pos.assign(0.)
        self.ctp.assign(0.)
        self.cfp.assign(0.)

# %%
def model():
        
    # Architecture
    inputs = keras.Input((1456, 728, 1), name='inputs')

    x = keras.ops.cast(inputs, tf.float32)
    x = keras.ops.repeat(x, repeats=3, axis=3)

    efficientnet = keras.applications.EfficientNetB4(
        weights='imagenet',
        input_shape=(1456, 728, 3),
        include_top=False,
        pooling="avg",
    )(x)


    x = keras.layers.Dropout(0.30)(efficientnet)
    outputs_1 = keras.layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs, outputs_1, name="model")
    #model.load_weights("whatthesssigma.weights.h5")

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
                      loss=tf.keras.losses.BinaryCrossentropy(), 
                      metrics=[pFBeta(),
                       tf.metrics.AUC(name='AUC'),
                       tf.metrics.F1Score(threshold=0.50, name='F1'),
                       tf.metrics.Precision(name='Prec'),
                       tf.metrics.Recall(name='Reca'),
                       tf.metrics.BinaryAccuracy(name='BinAcc')])
    

    # Print the model summary
    print(model.summary())
    return model

    
tf.keras.backend.clear_session()
tf.config.optimizer.set_jit("autoclustering")

model = model()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "small_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inputs_1 (InputLayer)           │ (None, 1456, 728, 1)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast_1 (Cast)                   │ (None, 1456, 728, 1)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat (Repeat)                 │ (None, 1456, 728, 3)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb4 (Functional)     │ (None, 1792)           │    17,673,823 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1792)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,793 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,675,616 (67.43 MB)
#  Trainable params: 17,550,409 (66.95 MB)
#  Non-trainable params: 125,207 (489.09 KB)
# None

# %%
history = model.fit(
    x=train_dataset,
    epochs=25,
    validation_data=valid_dataset,
    class_weight={0: 1, 1: 5},
    steps_per_epoch=TRAIN_STEPS_PER_EPOCH)
with STRATEGY.scope():
    model.save("/kaggle/working/model_v8.keras")
